# %% [markdown]
# # Segment 2 Charts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
from src.pipeline import *
# %autoreload
from textwrap import wrap

from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score

# %%
path = 'Data/2017 Pew Research Center Science and News Survey/Segmentation_data.csv'

# %%
segment_vars = ['ENJOY', 'KNOWLEDGE', 'SCIOFTEN', 'TOPICS1']
data, segment_data = get_cluster_data(path, segment_vars)
gm3 = GaussianMixture(n_components = 3, covariance_type=  'spherical', random_state=20)
gm3.fit(segment_data)
labelsg3 = gm3.predict(segment_data)
database_datag3 = data.copy()
database_datag3['Segment'] = labelsg3
dfg_3 = get_database(database_datag3)

# %%
seg_2 = dfg_3.loc[:,2]

# %% [markdown]
# ### DEMOGRAPHICS

# %%
## Gender
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Male', 'Female')
sizes = (seg_2['Male'], 
         seg_2['Female'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Gender')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticks(ticks = (0.0, 1.0))
ax.set_xticklabels(('Male', 'Female'))

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_gender.png')

# %%
## Age
fig, ax = plt.subplots(figsize = (10,8))
segments = ('18-24', '25-34', '35-44', '45-54', '55-64', '65-74', '75+')
sizes = (seg_2['18-24 years old'], 
         seg_2['25-34 years old'], 
         seg_2['35-44 years old'], 
         seg_2['45-54 years old'],
         seg_2['55-64 years old'], 
         seg_2['65-74'], 
         seg_2['75+'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Age')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_age.png')

# %%
## Income
fig, ax = plt.subplots(figsize = (10,8))
segments = ('<$20k', '$20 - $40k', '$40 - $60k', '$60 - $85k', '$85 - $125k',
            '$125 - $175k', '$175 - $200k', '$200k+')
sizes = (seg_2['<$20,000'], 
         seg_2['$20,000 - $40,000'], 
         seg_2['$40,000 - $60,000'], 
         seg_2['$60,000 - $85,000'],
         seg_2['$85,000 - $125,000'], 
         seg_2['$125,000 - $175,000'], 
         seg_2['$175,000 - $200,000'], 
         seg_2['$200,000+'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Income')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_income.png')

# %%
## Marital Status
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Married', 'Widowed', 'Divorced', 'Separated', 'Never Married',
            'Living with partner')
sizes = (seg_2['Married'], 
         seg_2['Widowed'], 
         seg_2['Divorced'], 
         seg_2['Separated'],
         seg_2['Never Married'],
         seg_2['Living with partner'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Marital Status')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()   
plt.savefig('static/img/segment2/demographics/seg2_maritalstatus.png')

# %%
## Education
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Less than HS', 'High School', 'Some College', 'Bachelor\'s +')
sizes = (seg_2['Completed less than HS education'],
         seg_2['Completed HS education'], 
         seg_2['Completed some college education'],
         seg_2['Completed Bachelors degree or higher'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Education Completed')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_education.png')

# %%
## Ethnicity
fig, ax = plt.subplots(figsize = (10,8))
segments = ('White', 'Black', 'Other', 'Hispanic', '2+ Races')
sizes = (seg_2['White, non-hispanic'], 
         seg_2['Black, non-hispanic'], 
         seg_2['Other, non-hispanic'], 
         seg_2['Hispanic'],
         seg_2['2+ races, non-hispanic'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Ethnicity')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_ethnicity.png')

# %%
## Region
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Northeast', 'Midwest', 'South', 'West')
sizes = (seg_2['Northeast Region'], 
         seg_2['Midwest Region'], 
         seg_2['South Region'], 
         seg_2['West Region'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Region')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_region.png')

# %%
## Parent
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Parent', 'Not a Parent')
sizes = (seg_2['I am the parent of a 0-17 year old'],
         seg_2['I am not the parent of a 0-17 year old'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Parent')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
    
plt.tight_layout()
plt.savefig('static/img/segment2/demographics/seg2_parent.png')

# %%
## Political Views
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Very Conservative', 'Conservative', 'Moderate', 'Liberal', 'Very Liberal')
sizes = (seg_2['My political views are Very Conservative'], 
         seg_2['My political views are Conservative'],
         seg_2['My political views are Moderate'], 
         seg_2['My political views are Liberal'],
         seg_2['My political views are Very Liberal'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Political Stance')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_politicalviews.png')

# %%
## Political Party
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Republican', 'Democrat', 'Independent', 'Other')
sizes = (seg_2['I consider myself a Republican'], 
         seg_2['I consider myself a Democrat'],
         seg_2['I consider myself an Independent'], 
         seg_2['I consider myself a different party'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Political Party')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/demographics/seg2_politicalparty.png')

# %% [markdown]
# ### SCIENCE NEWS

# %%
## Frequency
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Daily', 'Weekly', 'Monthly', 'Less Than Monthly')
sizes = (seg_2['I read, watch or listen to science news nearly every day'], 
         seg_2['I read, watch or listen to science news a few times a week'],
         seg_2['I read, watch or listen to science news a few times a month'], 
         seg_2['I read, watch or listen to science news less often than a few times a month'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Science News Frequency')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_frequency.png')

# %%
## Topics
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Health & Medicine', 'Tech', 'Energy/ Environ.', 'Food/ Nutrition', 'Space/ Astronomy',
           'Evolution', 'Mind & Brain')
segments = ['\n'.join(wrap(l, 9)) for l in segments]
sizes = (seg_2['Most interested in health & medicine'], 
         seg_2['Most interested in technology'],
         seg_2['Most interested in energy and environment'], 
         seg_2['Most interested in food and nutrition'],
         seg_2['Most interested in space and astronomy'], 
         seg_2['Most interested in evolution of human & animals'],
         seg_2['Most interested in the mind and brain'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Topics Most Interested In')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_topics.png')

# %%
## Where get
fig, ax = plt.subplots(figsize = (10,8))
segments = ('A Couple Sources', 'Many Different Sources')
sizes = (seg_2['Get science news from a couple sources'], 
         seg_2['Get science news from many different sources'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Where Get Science News From')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_whereget.png')

# %%
## Source Type
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Specialize in Science', 'Covers many Topics')
sizes = (seg_2['Get science news from sources that specialize in science topics'], 
         seg_2['Get science news sources that cover all sorts of topics'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Source Type')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_sourcetype.png')

# %%
## Enjoy
fig, ax = plt.subplots(figsize = (10,8))
segments = ('A lot more than other news', 'More than other news', 'Less than other news', 'A lot less than other news')
segments = ['\n'.join(wrap(l, 20)) for l in segments]
sizes = (seg_2['Enjoy science news a lot more than other news'], 
         seg_2['Enjoy science news more than other news'],
         seg_2['Enjoy science news less than other news'],
         seg_2['Enjoy science news a lot less than other news'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('How Much Enjoy Science News')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_enjoy.png')

# %%
## Knowledge
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Know a lot', 'Know some', 'Don\'t know much', 'Don\'t know anything')
sizes = (seg_2['I know a lot about science'], 
         seg_2['I know some about science'],
         seg_2['I know not much about science'],
         seg_2['I know nothing at all about science'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('How Much Know About Science News')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_know.png')

# %%
## How Get Science News
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Looking for it', 'Happen across it')
sizes = (seg_2['I mostly get science news because I\'m looking for it'], 
         seg_2['I mostly get science news because I happen to come across it'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('How Get Science News')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_getnews.png')

# %%
## Reasons Why Follow
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Enjoy talking with others about it', 'Related to my job', 'Helps make life decisions',
           'Have a civil obligation to stay informed', 'Curious about what\'s happening',
           'Related to my hobbies/interests')

segments = ['\n'.join(wrap(l, 20)) for l in segments]

sizes = (100-seg_2['Enjoy talking with others about what\'s happening in science is not a reason to follow science news'],
         100-seg_2['It is related to things I need to know for my job is not a reason to follow science news'],
         100-seg_2['Helps me make decision about every day life is not a reason to follow science news'],
         100-seg_2['I feel I have a social or civil obligation to stay informed is not a reason to follow science news'],
         100-seg_2['I am curious about what\'s happening in science is not a reason to follow science news'],
         100-seg_2['It is related to my activities, hobbies or interests is not a reason to follow science news'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('(Major or Minor) Reasons To Follow Science News')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments, {'rotation': 45})

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
    
plt.tight_layout()
plt.savefig('static/img/segment2/scinews/seg2_why.png')

# %%
## Reasons Why Not Follow
fig, ax = plt.subplots(figsize = (10,8))
segments = ('It\'s boring', 'It\'s hard to understand', 'I disagree with it',
            'It\'s less important than other news', 'I\'m too busy to keep up',
            'Already get enough', 'Sources I get regular news from don\'t cover',
           'The topics I\'m interested in aren\'t covered')

segments = ['\n'.join(wrap(l, 20)) for l in segments]

sizes = (100-seg_2['Science news is boring is not a reason to not follow science news'],
         100-seg_2['Science news is hard to understand is not a reason to not follow science news'],
         100-seg_2['I often disagree with science news is not a reason to not follow science news'],
         100-seg_2['Science news is less important than other topics is not a reason to not follow science news'],
         100-seg_2['I am too busy to keep up with science news more often is not a reason to not follow science news'],
         100-seg_2['I already get enough science news is not a reason to not follow science news'],
         100-seg_2['The sources I regulary get news from don\'t cover a lot of science is not a reason to not follow science news'],
         100-seg_2['The science topics I\'m most interested in are not covered often is not a reason to not follow science news'],
        )
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('(Major or Minor) Reasons To Not Follow Science News')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments, {'rotation': 45})

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()   
plt.savefig('static/img/segment2/scinews/seg2_whynot.png')

# %%
## Discuss Frequency
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Daily', 'Weekly', 'Monthly', 'Less often')
sizes = (seg_2['I discuss science news with others nearly every day'], 
         seg_2['I discuss science news with others a few times a week'],
         seg_2['I discuss science news with others a few times a month'],
         seg_2['I discuss science news with others less often than few times a month'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Discuss Science News Frequency')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/scinews/seg2_discuss.png')

# %%
## News Types
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Governmnet & Politics', 'Local Community News', 'Sports News', 'Business/Finance News', 
            'Science News', 'Entertainment News')
sizes = (seg_2['Interested in government and politics news'], 
         seg_2['Interested in local community news'],
         seg_2['Interested in sports news'],
         seg_2['Interested in business and finance news'],
         seg_2['Interested in science news'],
         seg_2['Interested in entertainment news'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('(Very or Somewhat) Intersted in Different News Types')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments, {'rotation': 45})

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
    
plt.tight_layout()
plt.savefig('static/img/segment2/scinews/seg2_newstypes.png')

# %% [markdown]
# ### GENERAL NEWS

# %%
## News Reporting
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Very Good Job', 'Somewhat Good Job', 'Somewhat Bad Job', 'Very Bad Job')
sizes = (seg_2['News media does a very good job in covering science'], 
         seg_2['News media does a somewhat good job in covering science'],
         seg_2['News media does a somewhat bad job in covering science'],
         seg_2['News media does a very bad job in covering science'])
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('News Media Performance on Covering Science News')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/gennews/seg2_newsjob.png')

# %%
## News Reporting Get Correct
fig, ax = plt.subplots(figsize = (10,8))
segments = ('News Outlets Covering Range of Topics',
            'Documentaries',
            'Science Magazines', 
            'Science Online Discussion Forums',
            'Science Podcasts or Radio Programs', 
            'Family & Friends',
            'Government Agencies',
            'Advocacy Organizations',
            'Science Tech Centers/Museums')

segments = ['\n'.join(wrap(l, 20)) for l in segments]

sizes = (seg_2['News outlets that cover a range of topics get the facts right almost all or more than half of the time'], 
         seg_2['Documentaries or other science video programs get the facts right almost all or more than half of the time'],
         seg_2['Science magazines (print/online) get the facts right almost all or more than half of the time'],
         seg_2['Online discussion forums about science get the facts right almost all or more than half of the time'],
         seg_2['Science podcasts or radio programs get the facts right almost all or more than half of the time'],
         seg_2['Family, friends & acquaintances get the facts right almost all or more than half of the time'],
         seg_2['Government agencies get the facts right almost all or more than half of the time'],
         seg_2['Advocacy organizations get the facts right almost all or more than half of the time'],
         seg_2['Science technology centers or museums get the facts right almost all or more than half of the time'])

ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Sources That Get Facts Right (Almost All or More than Half) of the Time')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments, {'rotation': 45})

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/gennews/seg2_sourcesright.png')

# %%
## News Rerporting Problems
fig, ax = plt.subplots(figsize = (10,8))
segments = ('News media are too quick to report findings',
            'News media covers too many unimportant findings',
            'Too many studies to distinguish high and low quality', 
            'Public jumps to conclusions about applying findings to life',
            'Public doesn\'t know enough to understand findings', 
            'News media oversimplify findings',
            'Science researchers overstate implications',
            'News media are too quick to report disagreements on findings')

segments = ['\n'.join(wrap(l, 20)) for l in segments]

sizes = (100 - seg_2['The news media are too quick to report research findings that may not hold up is not a problem'], 
         100 - seg_2['The news media cover too many research findings that are not really important is not a problem'],
         100 - seg_2['There are so many research studies it\'s hard to distinguish between high and low quality is not a problem'],
         100 - seg_2['The public jumps to conclusions about how to apply new research findings to their lives is not a problem'],
         100 - seg_2['The public doesn\'t know enough about science to really understand research findings covered in news is not a problem'],
         100 - seg_2['The news media oversimplifies scientific research findings is not a problem'],
         100 - seg_2['Science researchers overstate the implications of their findings is not a problem'],
         100 - seg_2['The news media are too quick to report on disagreement about research findings is not a problem'])

ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Problems (Big or Small) With Reporting Science News Research Findings')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments, {'rotation': 45})

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/gennews/seg2_problems.png')

# %% [markdown]
# ### OTHER BEHAVIORS

# %%
## Life Outlook
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Life is better than 50 yrs ago',
            'Life is worse than 50 yrs ago',
            'Life is the same as 50 yrs ago')

sizes = (seg_2['Life is better than 50 yrs ago'], 
         seg_2['Life is worse than 50 yrs ago'],
         seg_2['Life is the same as 50 yrs ago'])
         
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Outlook on Life')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/behavior/seg2_life.png')

# %%
## Social Media Freq
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Several times a day',
            'Once a day',
            'Few times a week',
            'Every few weeks',
            'Less often',
            'Don\'t use')

sizes = (seg_2['Use social media several times a day'], 
         seg_2['Use social media about once a day'],
         seg_2['Use social media a few times a week'],
         seg_2['Use social every few weeks'],
         seg_2['Use social media less often than every few weeks'],
         seg_2['SNSFREQ: Not Asked'])
         
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Social Media Use Frequency')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/behavior/seg2_socialmediafreq.png')

# %%
## Show Types Watch
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Criminal Investigation Shows',
            'Hospital & Medical Setting Shows',
            'Science Fiction Shows')

sizes = (seg_2['I typically watch entertainment programs on CRIMINAL INVESTIGATIONS'], 
         seg_2['I typically watch entertainment programs on HOSPITALS AND MEDICAL SETTINGS'],
         seg_2['I often watch entertainment programs on SCIENCE FICTION'])
         
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Entertainment Shows Typically Watch')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/behavior/seg2_entshows.png')

# %%
## Show Types Watch Portrayl of Science
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Criminal Investigation Shows',
            'Hospital & Medical Setting Shows',
            'Science Fiction Shows')

sizes = (seg_2['CRIMINAL INVESTIGATION shows generally portray science, tech & medicine in a realistic way'], 
         seg_2['HOSPITALS AND MEDICAL SETTINGS shows generally portray science, tech & medicine in a realistic way'],
         seg_2['SCIENCE FICTION shows generally portray science, tech & medicine in a realistic way'])
         
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Entertainment Shows Portray Science in Realistic Way vs. Focus on Entertaiment')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/behavior/seg2_entshowsportray.png')

# %%
## Show Types Watch Help Understand Science
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Criminal Investigation Shows',
            'Hospital & Medical Setting Shows',
            'Science Fiction Shows')

sizes = (seg_2['Watching CRIMINAL INVESTIGATION shows helps my understanding of science, tech & medicine'], 
         seg_2['Watching HOSPITALS AND MEDICAL SETTINGS shows helps my understanding of science, tech & medicine'],
         seg_2['Watching SCIENCE FICTION shows helps my understanding of science, tech & medicine'])
         
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Entertainment Shows Help Understanding of Science')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/behavior/seg2_entshowsunderstand.png')

# %%
## Show Types Watch Impression on Sci jobs
fig, ax = plt.subplots(figsize = (10,8))
segments = ('Criminal Investigation Shows',
            'Hospital & Medical Setting Shows',
            'Science Fiction Shows')

sizes = (seg_2['CRIMINAL INVESTIGATION shows give a favorable impression of working in science, tech & medicine'], 
         seg_2['HOSPITALS AND MEDICAL SETTINGS shows give a favorable impression of working in science, tech & medicine'],
         seg_2['SCIENCE FICTION shows give a favorable impression of working in science, tech & medicine'])
         
ax.bar(segments, height = sizes, color = '#fbc658')
ax.set_ylabel('%')
ax.set_title('Entertainment Shows Give Favorable Impression of Science')
ax.set_ylim(bottom = 0, top = 100)
ax.set_xticklabels(segments)

rects = ax.patches
# Make some labels
labels = ["{:2.0f}%".format(size) for size in sizes]

for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width() / 2, height + .5, label,
            ha='center', va='bottom')
plt.tight_layout()    
plt.savefig('static/img/segment2/behavior/seg2_entshowsimpress.png')
